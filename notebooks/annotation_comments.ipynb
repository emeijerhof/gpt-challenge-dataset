# %%
import json
import numpy as np
import pandas as pd
import re

from pathlib import Path

# %%
df = pd.read_json("./annotations/raw/erwin.json")
df.head()
# Out:
#      id                                               text   pairID
# 0  1506  Premise:\nInasmuch as there lacks an aerodrome...  124845c  \
# 1  1507  Premise:\nThe emperor hath been oft a minor, t...   57773e
# 2  1508  Premise:\nVerily, thou art aware that Arnold S...  109996n
# 3  1509  Premise:\nAye, apparently the appraisers be fa...    3476c
# 4  1510  Premise:\nThis bidding to play the soothsayer ...   21239e
#
#                                            orig_prem
# 0  Since there is no airport on the island, all v...  \
# 1  Very often the emperor was only a minor, so th...
# 2  you know Arnold Schwarzenegger is getting to b...
# 3  apparently apparently the appraisers likes it ...
# 4  This call to play fortuneteller is not easily ...
#
#                                             orig_hyp     orig_label
# 0   The best way to get onto the island is by plane.  contradiction  \
# 1  Sometimes the emperor was less than 18 years o...     entailment
# ...

# %%
for index, row in df[df["Comments"].astype(bool)].iterrows():
    print(row['Comments'])
    print(row['orig_prem'])
    print(row['orig_hyp'])
    print(row['orig_label'])
    print()
# Out:
# ['Questionable label on original']
# Unless the mention of the Ritz was an accidental remark?"
# Was mentioning the Ritz accidental and careless?
# entailment
#
# ['Questionable label on original']
# A museum inside the building gives intriguing insight into the life and heyday of the their rich costumes, their scimitars, and rifles inlaid with bright jewels and silver and a horrible bludgeon with a double serrated edge.
# The museum inside of the building features stuffed monkeys.
# contradiction
#
# ['Questionable original label']
# In the other sight he saw Adrin's hands cocking back a pair of dragon-hammered pistols.
# Adrin was seen cocking a pistol in each hand out of the corner of his eye.
# neutral
#
# ['Interesting intepretation of the hypothesis']
# Bien! he said at last.
# He wasted no time speaking.
# contradiction
#
# ['Aliens']
# ...
