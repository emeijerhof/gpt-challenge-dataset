# %%
import json
import pandas as pd
import re

from pathlib import Path

# %%
nmli_df = pd.read_json(f'./data/multinli_1.0/multinli_1.0_dev_matched.jsonl', lines=True)
nmli_df[nmli_df['gold_label'] == '-']
# Out:
#                                        annotator_labels       genre  \
# 111   [neutral, neutral, entailment, entailment, con...  government
# 114   [entailment, contradiction, neutral, neutral, ...       slate
# 159   [neutral, neutral, contradiction, entailment, ...      travel
# 211   [neutral, contradiction, entailment, neutral, ...  government
# 264   [entailment, neutral, contradiction, entailmen...       slate
# ...                                                 ...         ...
# 9730  [contradiction, contradiction, entailment, neu...       slate
# 9859  [neutral, entailment, entailment, neutral, con...       slate
# 9951  [contradiction, entailment, entailment, contra...       slate
# 9952  [neutral, contradiction, entailment, neutral, ...  government
# 9957  [neutral, entailment, contradiction, neutral, ...   telephone
#
#      gold_label   pairID  promptID  \
# 111           -  131718n    131718
# 114           -   70100e     70100
# 159           -   61611n     61611
# ...

# %%
with open('./results/annotation_subset.json') as f:
    annot = json.load(f)

with open('./results/annotation_subset_test.json', 'w') as f:
    f.write(json.dumps(annot[:5], indent=4))
